# %%
lst = [21,43,5,6,75,34,4]
final_lst = []

while len(lst) > 0:
    min_val : int
    for index,value in enumerate(lst):
        if index == 0:
            min_val = value
        else:
            if min_val > value:
                min_val = value
    final_lst.append(min_val)
    print(final_lst)
    idx = lst.index(min_val)
    lst.pop(idx)
# Out:
# [4]
# [4, 5]
# [4, 5, 6]
# [4, 5, 6, 21]
# [4, 5, 6, 21, 34]
# [4, 5, 6, 21, 34, 43]
# [4, 5, 6, 21, 34, 43, 75]

# %%
lst = [21,43,5,6,75,34,4]
final_lst = []
min_val : int

while len(lst) > 1:
    for index,value in enumerate(lst):    
        cur_val = value
        next_val = lst[index+ 1]
        if(cur_val < next_val):
            min_val = cur_val
        else:
            min_val = next_val
    final_lst.append(min_val)
    lst.pop(min_val)
final_lst.append(lst)
